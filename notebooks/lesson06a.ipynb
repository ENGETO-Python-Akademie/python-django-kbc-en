# %% [markdown]
# First a brief introductory presentation [kbc-django-intro-2026](https://docs.google.com/presentation/d/1vcuQmI49RuyDq_VX2bUHfNJ0f9fJG7XlHilp1fBvbDI/edit?usp=sharing).
#
# ---

# %% [markdown]
# # Django, Project Structure

# %% [markdown]
# ## Introduction to Django Projects
# ---

# %% [markdown]
# In this lesson, you'll learn how to **create and understand Django projects**.
#
# This is the foundation for building any web application with Django.

# %% [markdown]
# 1. [What is Django](#What-is-Django),
#     - [Why Django](#Why-Django),
#     - [Batteries Included Philosophy](#Batteries-Included-Philosophy),
# 2. [Creating a Django Project](#Creating-a-Django-Project),
#     - [Installing Django](#Installing-Django),
#     - [django-admin startproject](#django-admin-startproject),
# 3. [Project Structure](#Project-Structure),
#     - [Understanding the Generated Files](#Understanding-the-Generated-Files),
#     - [The Inner vs Outer Project Directory](#The-Inner-vs-Outer-Project-Directory),
# 4. [manage.py - Your Django Swiss Army Knife](#manage.py---Your-Django-Swiss-Army-Knife),
#     - [Essential Commands](#Essential-Commands),
#     - [Running the Development Server](#Running-the-Development-Server),
# 5. [🧠 EXERCISE 🧠, Create Your First Django Project](#🧠-EXERCISE-🧠,-Create-Your-First-Django-Project).
#
# <br>

# %% [markdown]
# ### A few questions and answers to start with
#
# ---
#
# <div style="text-align: center;">
#     <img src="../images/django-logo-2.png" width="280" height="260">
# </div>
#
# #### Why should I use Django?
# Allows you to quickly and easily build robust web applications.
#
# <br>
#
# #### What is Django, but in plain English?
# Django is a web framework for Python.
#
# Django lets you run a development server, locally (on your PC) while you’re building the project.
#
# <br>
#
# #### What is a framework in Python?
# It’s more than a library — it’s a structure for building projects.
#
# <br>
#
# ### What is a project?
# Its the entire web application. It includes settings, configuration and individual parts (applications).
#
# <br>
#
# #### How can Django help me?
# Instead of writing everything from scratch (users, database, forms, etc.), Django gives you a pre-built structure and a lot of already solved tools.
#
# ####

# %% [markdown]
# ### What is Django
#
# ---
#
# <div style="text-align: center;">
#     <img src="../images/toolbox.png" width="280" height="260">
# </div>

# %% [markdown]
# Imagine you want to build a house. You could start from scratch - making your own bricks, forging your own nails, cutting your own lumber.
#
# Or you could use **prefabricated components** that professionals have already designed and tested.
#
# <br>
#
# **Django** is like a prefabricated house kit for web applications. It provides:
#
# - 🗄️ A **database layer (ORM)** to store and retrieve data
# - 🛣️ A **URL routing system** to handle web requests
# - 🧩 A **template engine** to generate HTML
# - 🛠️ An **admin interface** out of the box
# - 🔒 **Security features** built-in (CSRF, XSS protection, etc.)
# - 👤 **Authentication system** ready to use

# %% [markdown]
# <br>
#
# ### Why Django
#
# ---

# %% [markdown]
# Django was created in 2003 at a newspaper company (Lawrence Journal-World) where developers needed to build web applications **quickly** with **tight deadlines**.
#
# <br>
#
# | Framework | Philosophy | Best For | Example projects |
# |-----------|------------|----------|------------------|
# | **Django** 🐍 | Batteries included 🔋 | Full-featured web apps, CMS, e-commerce | 🛒 E-shop, 📝 blog platform, 🏢 intranet system, 💼 SaaS applications |
# | Flask 🌶️ | Minimal, flexible | APIs, microservices, learning | 🔌 Simple REST API, 📱 mobile app backend, 🧪 service prototype |
# | FastAPI ⚡ | Modern, async-first | High-performance APIs | 🚀 Fast REST APIs, 🔗 microservices, 🤖 AI backend, 📊 data processing API |
#
# <br>
#
# **Choose Django when:**
# - You need a **full-featured web project** (not just an API)
# - You want an **admin interface** without building one
# - You prefer **convention over configuration**
# - You value **security** and **stability**

# %% [markdown]
# <br>
#
# ### Batteries Included Philosophy
#
# ---

# %% [markdown]
# Django's motto is **"The web framework for perfectionists with deadlines."**
#
# This means Django includes everything you need to build a web application:
#
# <br>
#
# | Component | What Django Provides |
# |-----------|---------------------|
# | Database | ORM with migrations |
# | Authentication | User model, login/logout, permissions |
# | Admin | Auto-generated admin interface |
# | Forms | Form handling and validation |
# | Security | CSRF, XSS, SQL injection protection |
# | Caching | Multiple cache backends |
# | Internationalization | Translation support |
#
# <br>
#
# You don't have to use all of these features, but they're there when you need them.

# %% [markdown]
# <br>
#
# ## Creating a Django Project
#
# ---

# %% [markdown]
# ### Installing Django
#
# ---

# %% [markdown]
# Before creating a project, you need to install Django and set up the project. **Always use an isolated environment!**
#
# **Prerequisites:**
# - Python 3.10+
# - `uv` installed and available in PATH (`uv --version`)
# - Recommended project environment name: `.venv`
#
# <br>
#
# **Linux/macOS:**
# ```bash
# # Check uv installation
# uv --version
#
# # Initialize project metadata (creates pyproject.toml)
# uv init --bare
#
# # Create project virtual environment
# uv venv .venv
#
# # Add Django dependency (updates pyproject.toml and uv.lock)
# uv add "django>=5.2,<6"
#
# # Sync environment from lockfile
# uv sync
#
# # Verify installation (runs inside project environment)
# uv run python -m django --version
# ```
#
# **Windows:**
# ```powershell
# # Check uv installation
# uv --version
#
# # Initialize project metadata (creates pyproject.toml)
# uv init --bare
#
# # Create project virtual environment
# uv venv .venv
#
# # Add Django dependency (updates pyproject.toml and uv.lock)
# uv add "django>=5.2,<6"
#
# # Sync environment from lockfile
# uv sync
#
# # Verify installation (runs inside project environment)
# uv run python -m django --version
# ```
#
# **Optional activation (only if you want to run `python` directly):**
# - Linux/macOS: `source .venv/bin/activate`
# - Windows PowerShell: `.venv\Scripts\Activate.ps1`
#
# **Optional compatibility export (`requirements.txt`):**
# ```bash
# uv export --format requirements-txt --no-hashes -o requirements.txt
# ```
#
# <br>
#
# #### 🧠 EXERCISE 🧠, create your own working environment
#
# To verify the result, run:
# ```bash
# uv run python -m django --version
# ```

# %% [markdown]
# <br>
#
# ### django-admin startproject
#
# ---

# %% [markdown]
# First, just check the path for Python:
# ```bash
# uv run python -c "import sys; print(sys.executable)"
# ```
# ..it should end like:
# - **Linux/MacOS**: `.../<current-dir>/.venv/bin/python3`
# - **Windows**: `...\<current-dir>\.venv\Scripts\python.exe`
#
# Django provides a command-line tool called `django-admin` that helps you create projects and apps.
#
# When working with `uv`, run Django commands through `uv run` so they always use the project virtual environment.
#
# <br>
#
# To create a new project:
# ```bash
# uv run django-admin startproject mysite  # It also creates a folder!
# ```
#
# <br>
#
# This creates a directory called `mysite` with the following structure:
#
# ```
# mysite/
# ├── manage.py
# └── mysite/
#     ├── __init__.py
#     ├── settings.py
#     ├── urls.py
#     ├── asgi.py
#     └── wsgi.py
# ```

# %% [markdown]
# <br>
#
# **Pro tip:** You can also create the project in the current directory:
#
# ```bash
# # Create project in current directory (note the dot at the end)
# uv run django-admin startproject mysite .
# ```
#
# This avoids the nested directory structure:
#
# ```
# ./                    # Current directory
# ├── manage.py
# └── mysite/
#     ├── __init__.py
#     ├── settings.py
#     └── ...
# ```

# %% [markdown]
# <br>
#
# ## Project Structure
#
# ---

# %% [markdown]
# ### Understanding the Generated Files
#
# ---

# %% [markdown]
# Let's understand what each file does:
#
# <br>
#
# | File | Purpose |
# |------|--------|
# | `manage.py` | Command-line utility to interact with your project |
# | `__init__.py` | Marks the directory as a Python package |
# | `settings.py` | Configuration for your Django project |
# | `urls.py` | URL declarations - the "table of contents" of your site |
# | `asgi.py` | Entry point for ASGI servers (async) |
# | `wsgi.py` | Entry point for WSGI servers (traditional) |

# %% [markdown]
# <br>
#
# **settings.py** - This is where you configure:
# - Database connections
# - Installed apps
# - Middleware
# - Templates
# - Static files
# - Security settings

# %%
# Example: Key settings in settings.py (for illustration)

# SECURITY WARNING: keep the secret key used in production secret!
SECRET_KEY = 'django-insecure-your-secret-key-here'

# SECURITY WARNING: don't run with debug turned on in production!
DEBUG = True

ALLOWED_HOSTS = []  # Add your domain names here in production

# Application definition
INSTALLED_APPS = [
    'django.contrib.admin',      # Admin interface
    'django.contrib.auth',       # Authentication system
    'django.contrib.contenttypes',
    'django.contrib.sessions',   # Session management
    'django.contrib.messages',   # Messaging framework
    'django.contrib.staticfiles', # Static file handling
]

# %% [markdown]
# <br>
#
# **urls.py** - Maps URLs to views:

# %%
# Example: Default urls.py content (for illustration)

from django.contrib import admin
from django.urls import path

urlpatterns = [
    path('admin/', admin.site.urls),  # Admin is available at /admin/
]

# %% [markdown]
# <br>
#
# ### The Inner vs Outer Project Directory
#
# ---

# %% [markdown]
# A common source of confusion is the **two directories with the same name**:
#
# ```
# mysite/           # OUTER: Root directory (can be renamed)
# ├── manage.py
# └── mysite/       # INNER: Python package (don't rename!)
#     ├── settings.py
#     └── ...
# ```
#
# <br>
#
# | Directory | Can Rename? | Purpose |
# |-----------|-------------|--------|
# | **Outer** `mysite/` | ✅ Yes | Just a container, can be anything |
# | **Inner** `mysite/` | ❌ No | Python package, referenced in settings |
#
# <br>
#
# ### 🧠 EXERCISE 🧠, create a new Django project
#
# To verify the project, run inside the project folder:
# ```bash
# uv run python manage.py runserver
# ```
#
# <br>
#
# The logs should look like:
# ```bash
# Watching for file changes with StatReloader
# Performing system checks...
#
# System check identified no issues (0 silenced).
#
# You have 18 unapplied migration(s). Your project may not work properly until you apply the migrations for app(s): admin, auth, contenttypes, sessions.
# Run 'python manage.py migrate' to apply them.
# ```
#
# If you would like to **stop the server**, click `Ctrl + C`.

# %% [markdown]
# <br>
#
# ## `manage.py` - Your Django Swiss Army Knife
#
# ---
# <div style="text-align: center;">
#     <img src="../images/swiss-knife.png" width="250" height="250">
# </div>

# %% [markdown]
# The `manage.py` file is your main interface to the Django project. It's essentially a thin wrapper around `django-admin` that:
#
# 1. Sets the `DJANGO_SETTINGS_MODULE` environment variable
# 2. Provides project-specific commands
#
# <br>
#
# **Syntax:**
# ```bash
# uv run python manage.py <command> [options]
# ```
# <br>
#
# **Help**
# ```bash
# uv run python manage.py help
# ```

# %% [markdown]
# <br>
#
# ### Essential Commands
#
# ---

# %% [markdown]
# Here are the most important `manage.py` commands you'll use daily:
#
# <br>
#
# | Command | Description |
# |---------|-------------|
# | `runserver` | Start the development server |
# | `migrate` | Apply database migrations |
# | `makemigrations` | Create new migrations based on model changes |
# | `createsuperuser` | Create an admin user |
# | `shell` | Open Python shell with Django context |
# | `startapp` | Create a new Django app |
# | `check` | Check for common problems |
# | `test` | Run tests |

# %% [markdown]
# <br>
#
# To see all available commands:
#
# ```bash
# python manage.py help
# ```
#
# To get help for a specific command:
#
# ```bash
# python manage.py help runserver
# ```

# %% [markdown]
# <br>
#
# ### Running the Development Server
#
# ---

# %% [markdown]
# The development server is a lightweight web server built into Django:
#
# ```bash
# uv run python manage.py runserver
# ```
#
# <br>
#
# **Output:**
# ```
# Watching for file changes with StatReloader
# Performing system checks...
#
# System check identified no issues (0 silenced).
#
# You have 18 unapplied migration(s)...
# Run 'python manage.py migrate' to apply them.
#
# February 25, 2026 - 10:00:00
# Django version 5.0, using settings 'mysite.settings'
# Starting development server at http://127.0.0.1:8000/
# Quit the server with CONTROL-C.
# ```
#
# - Django starts a simple server on your computer (e.g. `http://127.0.0.1:8000`).
# - It begins to ‘wait’ for HTTP requests (clicks in the browser, sending requests, ...).
# - For each request, it runs Django logic (URL → view → response).
# - Everything runs locally, only for development (not production).
#
# ```bash
# You (browser)
#      |
#      v
# http://localhost:8000
#      |
#      v
# +----------------------+
# | Django runserver     |
# | (dev web server)     |
# +----------------------+
#      |
#      v
# URL routing
#      |
#      v
# View (Python code)
#      |
#      v
# Response (HTML/JSON)
#      |
#      v
# Browser shows result
# ```

# %% [markdown]
# <br>
#
# **Customizing the server:**
#
# ```bash
# # Run on a different port
# python manage.py runserver 8080
#
# # Run on all interfaces (for network access)
# python manage.py runserver 0.0.0.0:8000
# ```
#
# <br>
#
# **Important:** The development server:
# - **Auto-reloads** when you change code
# - Is **NOT for production** - use `Gunicorn`, `uWSGI` (for production purposes).
# - Serves static files automatically (in `DEBUG mode`)
#
# <br>
#
# **Production environment**
# ```bash
#        CLIENT (Web Browser)
#
#                 |
#                 v  [ HTTP Protocol ]
#                 |
# +------------------------------------+
#
# |       NGINX (Web Server)           |  <-- "The Gatekeeper"
# | - Terminates SSL (HTTPS)           |      Handles security, caches,
# | - Serves Static Files (CSS, JS)    |      and acts as a Reverse Proxy.
# | - Buffers slow clients             |
# +---------------|--------------------+
#
#                 |
#                 v  [ Unix Socket / TCP ]
#                 |
# +------------------------------------+
#
# |  GUNICORN / uWSGI / ASGI           |  <-- "THE TRANSLATOR"
# | - Receives HTTP from Nginx         |      (Application Server)
# | - Translates it to WSGI/ASGI       |      Spawns & manages Python workers.
# | - Manages Worker Processes         |
# +---------------|--------------------+
#
#                 |
#                 v  [ WSGI / ASGI Call ]
#                 |
# +------------------------------------+
#
# |      DJANGO (Your Code)            |  <-- "The Brain"
# | - Executes Business Logic          |      Runs your views, models,
# | - Queries the Database             |      and middleware.
# | - Generates the Response           |
# +------------------------------------+
#
#                 |
#      (Response flows back up)
#                 v
#           THE TRANSLATOR  (Wraps Python results back into HTTP)
#                 |
#                 v
#               NGINX       (Sends the final HTTP packet to client)
#                 |
#                 v
#               CLIENT
#
# ```

# %% [markdown]
# <br>
#
# ## First Steps After Creating a Project
#
# ---

# %% [markdown]
# After creating your project, here's the typical workflow:
#
# <br>
#
# **1. Apply initial migrations** (creates database tables for built-in apps):
#
# ```bash
# python manage.py migrate
# ```
# Even if you don't have any models, Django needs to create database tables for built-in objects like users, admin, sessions.
#
# **2. Create a superuser** (admin account):
#
# ```bash
# python manage.py createsuperuser
# ```
#
# **3. Run the development server:**
#
# ```bash
# python manage.py runserver
# ```
#
# **4. Visit the admin interface:**
#
# Open `http://127.0.0.1:8000/admin/` in your browser and log in!

# %% [markdown]
# <br>
#
# ## Summary
#
# ---

# %% [markdown]
# | Concept | Key Points |
# |---------|------------|
# | **Django** | "Batteries included" web framework |
# | **Installation** | `uv add "django>=5.2,<6"` (records dependency in `pyproject.toml` + `uv.lock`) |
# | **Create project** | `django-admin startproject <name>` |
# | **Project structure** | `manage.py`, `settings.py`, `urls.py`, `wsgi.py`, `asgi.py` |
# | **manage.py** | Central entry point for commands |
# | **Key commands** | `runserver`, `migrate`, `createsuperuser`, `shell` |
# | **Dev server** | `python manage.py runserver` (NOT for production) |

# %% [markdown]
# <br>
#
# ### 🧠 EXERCISE 🧠, Create Your First Django Project
#
# ---

# %% [markdown]
# Practice what you've learned by completing the following tasks:
#
# 1. Create a new directory called `bookstore`
# 2. Navigate into the directory
# 3. Initialize project metadata with `uv init --bare`
# 4. Create a virtual environment called `.venv` with `uv`
# 5. Activate the virtual environment
# 6. Add Django with `uv add "django>=5.2,<6"`
# 7. Create a Django project called `bookstore_project` in the current directory (use the dot)
# 8. Apply the initial migrations
# 9. Create a superuser with your preferred credentials
# 10. Run the development server and open `http://127.0.0.1:8000/admin/`

# %% [markdown]
# <details>
#     <summary>▶️ Solution (Linux/macOS)</summary>
#
# ```bash
# # 1. Create directory
# mkdir bookstore
#
# # 2. Navigate into it
# cd bookstore
#
# # 3. Initialize uv project metadata
# uv init --bare
#
# # 4. Create virtual environment with uv
# uv venv .venv
#
# # 5. Activate
# source .venv/bin/activate
#
# # 6. Add Django dependency (saved in pyproject.toml + uv.lock)
# uv add "django>=5.2,<6"
#
# # 7. Create project (note the dot at the end!)
# django-admin startproject bookstore_project .
#
# # 8. Apply migrations
# python manage.py migrate
#
# # 9. Create superuser (follow the prompts)
# python manage.py createsuperuser
#
# # 10. Run server and open http://127.0.0.1:8000/admin/ in browser
# python manage.py runserver
# ```
# </details>

# %% [markdown]
# <details>
#     <summary>▶️ Solution (Windows PowerShell)</summary>
#
# ```powershell
# # 1. Create directory
# mkdir bookstore
#
# # 2. Navigate into it
# cd bookstore
#
# # 3. Initialize uv project metadata
# uv init --bare
#
# # 4. Create virtual environment with uv
# uv venv .venv
#
# # 5. Activate
# .venv\Scripts\Activate.ps1
#
# # 6. Add Django dependency (saved in pyproject.toml + uv.lock)
# uv add "django>=5.2,<6"
#
# # 7. Create project (note the dot at the end!)
# django-admin startproject bookstore_project .
#
# # 8. Apply migrations
# python manage.py migrate
#
# # 9. Create superuser (follow the prompts)
# python manage.py createsuperuser
#
# # 10. Run server and open http://127.0.0.1:8000/admin/ in browser
# python manage.py runserver
# ```
# </details>

# %% [markdown]
# <details>
#     <summary>▶️ Solution</summary>
#
# ```bash
# # 1. List all commands
# python manage.py help
# # You'll see categories: [auth], [contenttypes], [django], [sessions], [staticfiles]
#
# # 2. Check for issues
# python manage.py check
# # Expected: System check identified no issues (0 silenced).
#
# # 3. Open the shell
# python manage.py shell
#
# # 4. In the shell:
# >>> import django
# >>> print(django.VERSION)
# # Output: (5, 0, 0, 'final', 0)  # or similar
#
# # 5. Exit
# >>> exit()
# ```
# </details>

# %% [markdown]
# ---
